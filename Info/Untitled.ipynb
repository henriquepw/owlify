# %%
import matplotlib as mplot

# %%
data = open('endNode.txt', 'r')

# %%
l = data.read()

# %%
print(l)
# Out:
# [{"time":"2019-10-21T21:44:05.965Z","host":"test01","humidity":68.5,"temperature":25.8},{"time":"2019-10-21T21:43:59.421Z","host":"test01","humidity":68.5,"temperature":25.8},{"time":"2019-10-21T21:43:51.325Z","host":"test01","humidity":68.4,"temperature":25.8},{"time":"2019-10-21T21:43:45.304Z","host":"test01","humidity":68.4,"temperature":25.8},{"time":"2019-10-21T21:43:38.581Z","host":"test01","humidity":68.4,"temperature":25.8},{"time":"2019-10-21T21:43:25.741Z","host":"test01","humidity":68.3,"temperature":25.8},{"time":"2019-10-21T21:43:19.154Z","host":"test01","humidity":68.3,"temperature":25.8},{"time":"2019-10-21T21:43:13.003Z","host":"test01","humidity":68.3,"temperature":25.8},{"time":"2019-10-21T21:42:59.741Z","host":"test01","humidity":68.4,"temperature":25.8},{"time":"2019-10-21T21:42:51.652Z","host":"test01","humidity":68.4,"temperature":25.8},{"time":"2019-10-21T21:42:45.070Z","host":"test01","humidity":68.3,"temperature":25.8},{"time":"2019-10-21T21:42:38.584Z","host
# ...

# %%
aux = []
s = ''
ok = False
c = 0
for i in l:
    if i == '{':
        aux.append([])
        ok = True
    if ok == True:
        s += i
    if i == '}':
        ok = False
        aux[c].append(s)
        s = ''
        c += 1

# %%
for i in range(len(aux)):
    print(aux[i])
# Out:
# ['{"time":"2019-10-21T21:44:05.965Z","host":"test01","humidity":68.5,"temperature":25.8}']
# ['{"time":"2019-10-21T21:43:59.421Z","host":"test01","humidity":68.5,"temperature":25.8}']
# ['{"time":"2019-10-21T21:43:51.325Z","host":"test01","humidity":68.4,"temperature":25.8}']
# ['{"time":"2019-10-21T21:43:45.304Z","host":"test01","humidity":68.4,"temperature":25.8}']
# ['{"time":"2019-10-21T21:43:38.581Z","host":"test01","humidity":68.4,"temperature":25.8}']
# ['{"time":"2019-10-21T21:43:25.741Z","host":"test01","humidity":68.3,"temperature":25.8}']
# ['{"time":"2019-10-21T21:43:19.154Z","host":"test01","humidity":68.3,"temperature":25.8}']
# ['{"time":"2019-10-21T21:43:13.003Z","host":"test01","humidity":68.3,"temperature":25.8}']
# ['{"time":"2019-10-21T21:42:59.741Z","host":"test01","humidity":68.4,"temperature":25.8}']
# ['{"time":"2019-10-21T21:42:51.652Z","host":"test01","humidity":68.4,"temperature":25.8}']
# ...

# %%
gate = open('gateway.txt', 'r')

# %%
lista = gate.read()

# %%
print(lista)
# Out:
# [{"time":"2019-10-22T15:16:12.982Z","host":"test01","id":0,"rssi":-120,"snr":-12.25,"success":false},{"time":"2019-10-22T14:39:39.806Z","host":"test01","id":0,"rssi":-120,"snr":-12.25,"success":false},{"time":"2019-10-22T14:34:05.546Z","host":"test01","id":0,"rssi":-119,"snr":-12.25,"success":false},{"time":"2019-10-22T13:30:32.092Z","host":"test01","id":0,"rssi":-115,"snr":-12.5,"success":false},{"time":"2019-10-22T12:58:40.364Z","host":"test01","id":0,"rssi":-120,"snr":-12.5,"success":false},{"time":"2019-10-22T11:08:27.509Z","host":"test01","id":0,"rssi":-115,"snr":-12,"success":false},{"time":"2019-10-22T10:38:47.935Z","host":"test01","id":0,"rssi":-114,"snr":-11.75,"success":false},{"time":"2019-10-22T06:53:31.251Z","host":"test01","id":0,"rssi":-120,"snr":-12.25,"success":false},{"time":"2019-10-22T06:48:54.273Z","host":"test01","id":0,"rssi":-120,"snr":-11.75,"success":false},{"time":"2019-10-22T06:25:26.662Z","host":"test01","id":0,"rssi":-121,"snr":-12,"success":false},{"tim
# ...

# %%
aux2 = []
s = ''
ok = False
c = 0
for i in lista:
    if i == '{':
        aux2.append([])
        ok = True
    if ok == True:
        s += i
    if i == '}':
        ok = False
        aux2[c].append(s)
        s = ''
        c += 1

# %%
for i in range(len(aux2)):
    print(aux2[i])
# Out:
# ['{"time":"2019-10-22T15:16:12.982Z","host":"test01","id":0,"rssi":-120,"snr":-12.25,"success":false}']
# ['{"time":"2019-10-22T14:39:39.806Z","host":"test01","id":0,"rssi":-120,"snr":-12.25,"success":false}']
# ['{"time":"2019-10-22T14:34:05.546Z","host":"test01","id":0,"rssi":-119,"snr":-12.25,"success":false}']
# ['{"time":"2019-10-22T13:30:32.092Z","host":"test01","id":0,"rssi":-115,"snr":-12.5,"success":false}']
# ['{"time":"2019-10-22T12:58:40.364Z","host":"test01","id":0,"rssi":-120,"snr":-12.5,"success":false}']
# ['{"time":"2019-10-22T11:08:27.509Z","host":"test01","id":0,"rssi":-115,"snr":-12,"success":false}']
# ['{"time":"2019-10-22T10:38:47.935Z","host":"test01","id":0,"rssi":-114,"snr":-11.75,"success":false}']
# ['{"time":"2019-10-22T06:53:31.251Z","host":"test01","id":0,"rssi":-120,"snr":-12.25,"success":false}']
# ['{"time":"2019-10-22T06:48:54.273Z","host":"test01","id":0,"rssi":-120,"snr":-11.75,"success":false}']
# ...
